# %%
import pandas as pd


df_movies = pd.read_csv("movies.csv")
df_imdb = pd.read_csv("imdb_movies.csv")

print(df_movies.columns)
print(f"Number instances: {df_movies.shape[0]}")
print(df_imdb.columns)
print(f"Number instances: {df_imdb.shape[0]}")

common_movies = []

for movie_1 in df_movies["name"]:
    for movie_2 in df_imdb["orig_title"]:
        if movie_1 == movie_2:
            common_movies.append(movie_1)

print(f"Number common movies: {len(common_movies)}")
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')
# Number instances: 7668
# Index(['names', 'date_x', 'score', 'genre', 'overview', 'crew', 'orig_title',
#        'status', 'orig_lang', 'budget_x', 'revenue', 'country'],
#       dtype='object')
# Number instances: 10178
# Number common movies: 4241

# %%
df_merged = pd.merge(df_movies, df_imdb, left_on="name", right_on="orig_title")
df_merged["score_y"] = df_merged["score_y"] / 10
df_merged["rating_diff"] = df_merged["score_x"] - df_merged["score_y"]
df_merged["rating_diff_abs"] = df_merged["rating_diff"].abs()
df_merged["rating_diff_abs"].describe()
# Out:
# count    4241.000000
# mean        0.374841
# std         0.500967
# min         0.000000
# 25%         0.100000
# 50%         0.200000
# 75%         0.400000
# max         7.600000
# Name: rating_diff_abs, dtype: float64

# %%
# df_merged.head()
df_slim = df_merged.drop(["released", "date_x", "overview", "status"], axis=1)
df_slim.head()
# Out:
#               name rating    genre_x  year  score_x     votes  \
# 0      The Shining      R      Drama  1980      8.4  927000.0
# 1  The Blue Lagoon      R  Adventure  1980      5.8   65000.0
# 2        Airplane!     PG     Comedy  1980      7.7  221000.0
# 3       Caddyshack      R     Comedy  1980      7.3  108000.0
# 4  Friday the 13th      R     Horror  1980      6.4  123000.0
#
#              director                   writer            star  \
# 0     Stanley Kubrick             Stephen King  Jack Nicholson
# 1      Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
# 2        Jim Abrahams             Jim Abrahams     Robert Hays
# 3        Harold Ramis       Brian Doyle-Murray     Chevy Chase
# 4  Sean S. Cunningham            Victor Miller    Betsy Palmer
#
#         country_x  ...  score_y             genre_y  \
# 0  United Kingdom  ...      8.2    Horror, Thriller
# 1   United States  ...      6.2  Romance, Adventure
# 2   United States  ...      7.3              Comedy
# 3   United States  ...      6.6              Comedy
# 4   United States  ...      6.4              Horror
#
#                                                 crew       orig_title  \
# 0  Jack Nicholson, Jack Torrance, Shelley Duvall,...      The Shining
# 1  Brooke Shields, Emmeline, Christopher Atkins, ...  The Blue Lagoon
# 2  Robert Hays, Ted Striker, Julie Hagerty, Elain...        Airplane!
# 3  Chevy Chase, Ty Webb, Rodney Dangerfield, Al C...       Caddyshack
# 4  Betsy Palmer, Mrs. Voorhees, Adrienne King, Al...  Friday the 13th
#
#   orig_lang    budget_x     revenue country_y rating_diff rating_diff_abs
# 0   English  19000000.0  45613093.0        AU         0.2             0.2
# 1   English   4500000.0  47923795.0        AU        -0.4             0.4
# 2   English   3500000.0  83453539.0        AU         0.4             0.4
# 3   English   6000000.0  39849764.0        AU         0.7             0.7
# 4   English  17000000.0  92670237.0        AU         0.0             0.0
#
# [5 rows x 25 columns]

# %%
for movie_title in common_movies[:5]:
    imdb_row = df_imdb[df_imdb["orig_title"] == movie_title].iloc[0]
    print(imdb_row)
    movie_row = df_movies[df_movies["name"] == movie_title].iloc[0]
    print(movie_row)
# Out:
# names                                               The Shining
# date_x                                              11/13/1980
# score                                                      82.0
# genre                                          Horror, Thriller
# overview      Jack Torrance accepts a caretaker job at the O...
# crew          Jack Nicholson, Jack Torrance, Shelley Duvall,...
# orig_title                                          The Shining
# status                                                 Released
# orig_lang                                               English
# budget_x                                             19000000.0
# revenue                                              45613093.0
# country                                                      AU
# Name: 1912, dtype: object
# name                          The Shining
# rating                                  R
# genre                               Drama
# year                                 1980
# released    June 13, 1980 (United States)
# score                                 8.4
# votes                            927000.0
# director                  Stanley Kubrick
# writer                       Stephen King
# star                       Jack Nicholson
# country                    United Kingdom
# budget                         19000000.0
# gross                          46998772.0
# company                      Warner Bros.
# runtime                             146.0
# Name: 0, dtype: object
# names                                           The Blue Lagoon
# date_x                                              11/27/1980
# score                                                      62.0
# genre                                        Romance, Adventure
# overview      Two small children and a ship's cook survive a...
# crew          Brooke Shields, Emmeline, Christopher Atkins, ...
# orig_title                                      The Blue Lagoon
# status                                                 Released
# orig_lang                                               English
# budget_x                                              4500000.0
# revenue                                              47923795.0
# country                                                      AU
# Name: 2483, dtype: object
# name                     The Blue Lagoon
# rating                                 R
# genre                          Adventure
# year                                1980
# released    July 2, 1980 (United States)
# score                                5.8
# votes                            65000.0
# director                  Randal Kleiser
# writer           Henry De Vere Stacpoole
# star                      Brooke Shields
# country                    United States
# budget                         4500000.0
# gross                         58853106.0
# company                Columbia Pictures
# runtime                            104.0
# Name: 1, dtype: object
# names                                                 Airplane!
# date_x                                              12/12/1980
# score                                                      73.0
# genre                                                    Comedy
# overview      An ex-fighter pilot forced to take over the co...
# crew          Robert Hays, Ted Striker, Julie Hagerty, Elain...
# orig_title                                            Airplane!
# status                                                 Released
# orig_lang                                               English
# budget_x                                              3500000.0
# revenue                                              83453539.0
# country                                                      AU
# Name: 3149, dtype: object
# name                           Airplane!
# rating                                PG
# genre                             Comedy
# year                                1980
# released    July 2, 1980 (United States)
# score                                7.7
# votes                           221000.0
# director                    Jim Abrahams
# writer                      Jim Abrahams
# star                         Robert Hays
# country                    United States
# budget                         3500000.0
# gross                         83453539.0
# company               Paramount Pictures
# runtime                             88.0
# Name: 3, dtype: object
# names                                                Caddyshack
# date_x                                              08/21/1980
# score                                                      66.0
# genre                                                    Comedy
# overview      At an exclusive country club, an ambitious you...
# crew          Chevy Chase, Ty Webb, Rodney Dangerfield, Al C...
# orig_title                                           Caddyshack
# status                                                 Released
# orig_lang                                               English
# budget_x                                              6000000.0
# revenue                                              39849764.0
# country                                                      AU
# Name: 9384, dtype: object
# name                           Caddyshack
# rating                                  R
# genre                              Comedy
# year                                 1980
# released    July 25, 1980 (United States)
# score                                 7.3
# votes                            108000.0
# director                     Harold Ramis
# writer                 Brian Doyle-Murray
# star                          Chevy Chase
# country                     United States
# budget                          6000000.0
# gross                          39846344.0
# company                    Orion Pictures
# runtime                              98.0
# Name: 4, dtype: object
# names                                           Friday the 13th
# date_x                                              06/12/1980
# score                                                      64.0
# genre                                                    Horror
# overview      Camp counselors are stalked and murdered by an...
# crew          Betsy Palmer, Mrs. Voorhees, Adrienne King, Al...
# orig_title                                      Friday the 13th
# status                                                 Released
# orig_lang                                               English
# budget_x                                             17000000.0
# revenue                                              92670237.0
# country                                                      AU
# Name: 2352, dtype: object
# name                    Friday the 13th
# rating                                R
# genre                            Horror
# year                               1980
# released    May 9, 1980 (United States)
# score                               6.4
# votes                          123000.0
# director             Sean S. Cunningham
# writer                    Victor Miller
# star                       Betsy Palmer
# country                   United States
# budget                         550000.0
# gross                        39754601.0
# company              Paramount Pictures
# runtime                            95.0
# Name: 5, dtype: object
